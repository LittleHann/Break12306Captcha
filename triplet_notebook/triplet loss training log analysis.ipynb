# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def parse_and_plot_log(log_name):
    with open(log_name) as log_reader:
        losses = []
        iterations = []
        for line in log_reader:
            i_loss = line.find('loss = ')
            if i_loss > 0:
                iterations.append(len(losses) * 5)
                losses.append(float(line[i_loss + 7:]))
    plt.plot(iterations, losses)

# %%
margin01_fname = '../data/margin_0.1.log'
parse_and_plot_log(margin01_fname)

# %%
margin05_fname = '../data/margin_0.5.log'
parse_and_plot_log(margin05_fname)

# %%
new_margin_01_fname = '/home/haonans/capstone/log/margin_01.log'
parse_and_plot_log(new_margin_01_fname)
